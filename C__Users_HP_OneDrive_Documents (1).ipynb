# %% [markdown]
# # Play Store Apps Analysis and Visualization

# %% [markdown]
# TODO - Pre-processing the data
# TODO - Talk about exploratory data analysis
# TODO - Talk about the dataset (what it contains , how it will be useful )
#      - contains information about playstore apps
#      - conatins information about app reviews
#      - can be useful to find out which app is easy and safe to use

# %%
import pandas as pd
import numpy as np

# %%
Playstore_apps_df = pd.read_csv("playstore_apps.csv",index_col = "App")
Playstore_reviews_df = pd.read_csv("playstore_reviews.csv",index_col = "App")

# %% [markdown]
# # TASK 1 :- Pre-Processing the data

# %% [markdown]
# SUBTASK 1 :- Removing Duplicate rows:
#
#          TODO - Load the file using pandas
#               - Look at the information which is provided in data frame about data and columns
#               - Remove the duplicate rows

# %%
Playstore_apps_df
# Out:
#                                                                Category  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook           ART_AND_DESIGN
# Coloring book moana                                      ART_AND_DESIGN
# U Launcher Lite – FREE Live Cool Themes, Hide Apps       ART_AND_DESIGN
# Sketch - Draw & Paint                                    ART_AND_DESIGN
# Pixel Draw - Number Art Coloring Book                    ART_AND_DESIGN
# ...                                                                 ...
# Sya9a Maroc - FR                                                 FAMILY
# Fr. Mike Schmitz Audio Teachings                                 FAMILY
# Parkinson Exercices FR                                          MEDICAL
# The SCP Foundation DB fr nn5n                       BOOKS_AND_REFERENCE
# iHoroscope - 2018 Daily Horoscope & Astrology                 LIFESTYLE
#
#                                                     Rating   Reviews  \
# App
# ...

# %%
Playstore_reviews_df
# Out:
#                                                              Translated_Review  \
# App
# 10 Best Foods for You        I like eat delicious food. That's I'm cooking ...
# 10 Best Foods for You          This help eating healthy exercise regular basis
# 10 Best Foods for You                                                      NaN
# 10 Best Foods for You               Works great especially going grocery store
# 10 Best Foods for You                                             Best idea us
# ...                                                                        ...
# Houzz Interior Design Ideas                                                NaN
# Houzz Interior Design Ideas                                                NaN
# Houzz Interior Design Ideas                                                NaN
# Houzz Interior Design Ideas                                                NaN
# Houzz Interior Design Ideas                                                NaN
#
# ...

# %%
#Drop duplicate rows using drop_duplicate() function
Playstore_apps_df.drop_duplicates(keep = False , inplace = True)
Playstore_reviews_df.drop_duplicates(keep = False , inplace = True)

# %%
Playstore_apps_df
# Out:
#                                                                Category  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook           ART_AND_DESIGN
# Coloring book moana                                      ART_AND_DESIGN
# U Launcher Lite – FREE Live Cool Themes, Hide Apps       ART_AND_DESIGN
# Sketch - Draw & Paint                                    ART_AND_DESIGN
# Pixel Draw - Number Art Coloring Book                    ART_AND_DESIGN
# ...                                                                 ...
# Sya9a Maroc - FR                                                 FAMILY
# Fr. Mike Schmitz Audio Teachings                                 FAMILY
# Parkinson Exercices FR                                          MEDICAL
# The SCP Foundation DB fr nn5n                       BOOKS_AND_REFERENCE
# iHoroscope - 2018 Daily Horoscope & Astrology                 LIFESTYLE
#
#                                                     Rating   Reviews  \
# App
# ...

# %%
Playstore_reviews_df
# Out:
#                                                                   Translated_Review  \
# App
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                                Almost mobile phone
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室  Very effective, efficient convenient find avai...
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                                     Easy intuitive
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                      good searching job internship
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                Not bad, price little bit expensive
# ...                                                                             ...
# Housing-Real Estate & Property    Most ads older many agents ..not much owner po...
# Housing-Real Estate & Property    If photos posted portal load, fit purpose. I'm...
# Housing-Real Estate & Property    Dumb app, I wanted post property rent give opt...
# Housing-Real Estate & Property    I property business got link SMS happy perform...
# ...

# %%
#Taking some random information
Playstore_apps_df.head(10)
# Out:
#                                                           Category  Rating  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook      ART_AND_DESIGN     4.1
# Coloring book moana                                 ART_AND_DESIGN     3.9
# U Launcher Lite – FREE Live Cool Themes, Hide Apps  ART_AND_DESIGN     4.7
# Sketch - Draw & Paint                               ART_AND_DESIGN     4.5
# Pixel Draw - Number Art Coloring Book               ART_AND_DESIGN     4.3
# Paper flowers instructions                          ART_AND_DESIGN     4.4
# Smoke Effect Photo Maker - Smoke Editor             ART_AND_DESIGN     3.8
# Infinite Painter                                    ART_AND_DESIGN     4.1
# Garden Coloring Book                                ART_AND_DESIGN     4.4
# Kids Paint Free - Drawing Fun                       ART_AND_DESIGN     4.7
#
#                                                      Reviews  Size  \
# App
# ...

# %%
#Taking some random information
Playstore_reviews_df.head(10)
# Out:
#                                                                   Translated_Review  \
# App
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                                Almost mobile phone
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室  Very effective, efficient convenient find avai...
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                                     Easy intuitive
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                      good searching job internship
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                Not bad, price little bit expensive
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                                          easy use!
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室               job search results iOS e.g. security
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室  Well, it is also the largest human bank in Tai...
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                                                 So
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                                 Very good job hunt
#
# ...

# %%
Playstore_apps_df.columns
# Out:
# Index(['Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price',
#        'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
Playstore_reviews_df.columns
# Out:
# Index(['Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
#Taking information about rows,columns and data types
Playstore_apps_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9930 entries, Photo Editor & Candy Camera & Grid & ScrapBook to iHoroscope - 2018 Daily Horoscope & Astrology
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        9930 non-null   object
#  1   Rating          8487 non-null   float64
#  2   Reviews         9929 non-null   float64
#  3   Size            9930 non-null   object
#  4   Installs        9929 non-null   float64
#  5   Type            9929 non-null   object
#  6   Price           9929 non-null   float64
#  7   Content Rating  9929 non-null   object
#  8   Genres          9930 non-null   object
#  9   Last Updated    9929 non-null   object
#  10  Current Ver     9922 non-null   object
#  11  Android Ver     9927 non-null   object
# dtypes: float64(4), object(8)
# memory usage: 1008.5+ KB

# %%
#Taking information about rows,columns and data types
Playstore_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22593 entries, 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室 to Housing-Real Estate & Property
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Translated_Review       22593 non-null  object
#  1   Sentiment               22593 non-null  object
#  2   Sentiment_Polarity      22593 non-null  float64
#  3   Sentiment_Subjectivity  22593 non-null  float64
# dtypes: float64(2), object(2)
# memory usage: 882.5+ KB

# %% [markdown]
# SUBTASK 2:- Remove irrelevent values from each column if any:
#
#         TODO  - By using .unique function get the list of all the unique values
#               - check all the unique values and their data types
#               - remove the unique values which does not comply with the column data type

# %% [markdown]
# A) PERFROMING TASK FOR Playstore_apps_df :-

# %%
#Checking the unique values in Playstore_apps_df of 'category' column
Playstore_apps_df['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
# All the values except 1.9 in the category column are of string data type so remove 1.9
Playstore_apps_df =  Playstore_apps_df[Playstore_apps_df['Category']  !='1.9']

# %%
Playstore_apps_df['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %%
Playstore_apps_df['Category'].dtype
# Out:
# dtype('O')

# %%
#change data type to string
Playstore_apps_df['Category'].astype("string")
# Out:
# App
# Photo Editor & Candy Camera & Grid & ScrapBook             ART_AND_DESIGN
# Coloring book moana                                        ART_AND_DESIGN
# U Launcher Lite – FREE Live Cool Themes, Hide Apps         ART_AND_DESIGN
# Sketch - Draw & Paint                                      ART_AND_DESIGN
# Pixel Draw - Number Art Coloring Book                      ART_AND_DESIGN
#                                                              ...
# Sya9a Maroc - FR                                                   FAMILY
# Fr. Mike Schmitz Audio Teachings                                   FAMILY
# Parkinson Exercices FR                                            MEDICAL
# The SCP Foundation DB fr nn5n                         BOOKS_AND_REFERENCE
# iHoroscope - 2018 Daily Horoscope & Astrology                   LIFESTYLE
# Name: Category, Length: 9929, dtype: string

# %%
#Checking the unique values in Playstore_apps_df of 'Rating' column
Playstore_apps_df['Rating'].unique()
# Out:
# array([4.1, 3.9, 4.7, 4.5, 4.3, 4.4, 3.8, 4.2, 4.6, 3.2, 4. , nan, 4.8,
#        4.9, 3.6, 3.7, 3.3, 3.4, 3.5, 3.1, 5. , 2.6, 3. , 2.5, 1. , 1.9,
#        2.9, 2.8, 2.3, 2.2, 1.7, 2. , 1.8, 2.7, 2.4, 1.6, 2.1, 1.4, 1.5,
#        1.2])

# %%
Playstore_apps_df['Rating'].dtype
# Out:
# dtype('float64')

# %%
#Checking the unique values in Playstore_apps_df of 'Reviews' column
Playstore_apps_df['Reviews'].unique()
# Out:
# array([1.59000e+02, 9.67000e+02, 8.75100e+04, ..., 6.03000e+02,
#        1.19500e+03, 3.98307e+05])

# %%
list(Playstore_apps_df['Reviews'].unique())
# Out:
# [159.0,
#  967.0,
#  87510.0,
#  215644.0,
#  167.0,
#  178.0,
#  36815.0,
#  13791.0,
#  121.0,
#  13880.0,
#  8788.0,
#  44829.0,
#  4326.0,
#  1518.0,
#  55.0,
#  3632.0,
#  27.0,
#  194216.0,
#  224399.0,
#  450.0,
#  654.0,
#  7699.0,
#  61.0,
#  118.0,
#  192.0,
#  20260.0,
#  203.0,
#  136.0,
#  223.0,
#  1120.0,
#  227.0,
#  5035.0,
#  1015.0,
#  353.0,
#  564.0,
#  8145.0,
#  36639.0,
#  158.0,
#  591.0,
#  117.0,
#  176.0,
#  295221.0,
#  2206.0,
#  26.0,
#  174531.0,
#  1070.0,
#  85.0,
#  845.0,
#  367.0,
#  1598.0,
#  284.0,
#  17057.0,
#  129.0,
#  542.0,
#  10479.0,
#  805.0,
#  1403.0,
#  3971.0,
#  534.0,
#  7774.0,
#  38846.0,
#  2431.0,
#  6090.0,
#  295.0,
#  190.0,
#  40211.0,
#  356.0,
#  52530.0,
#  116986.0,
#  1379.0,
#  271920.0,
#  736.0,
#  7021.0,
#  197.0,
#  737.0,
#  3574.0,
#  994.0,
#  197136.0,
#  142.0,
#  15168.0,
#  2155.0,
#  138.0,
#  5414.0,
#  21777.0,
#  348.0,
#  250.0,
#  13372.0,
#  7880.0,
#  3617.0,
#  4806.0,
#  65786.0,
#  31433.0,
# ...

# %%
Playstore_apps_df['Reviews'].dtype
# Out:
# dtype('float64')

# %%
#Checking the unique values in Playstore_apps_df of 'Size' column
Playstore_apps_df["Size"].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '46M', '8.3M', '4.3M', '4.7M',
#        '3.3M', '40M', '7.8M', '8.8M', '6.6M', '5.1M', '61M', '66M', '79k',
# ...

# %%
Playstore_apps_df = Playstore_apps_df[Playstore_apps_df["Size"] != "Varies with device"]

# %%
Playstore_apps_df["Size"].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', '9.4M', '15M', '10M', '1.2M', '26M', '8.0M',
#        '7.9M', '56M', '57M', '35M', '54M', '201k', '3.6M', '5.7M', '8.6M',
#        '2.4M', '27M', '2.5M', '16M', '3.4M', '8.9M', '3.9M', '2.9M',
#        '38M', '32M', '5.4M', '18M', '1.1M', '2.2M', '4.5M', '9.8M', '52M',
#        '9.0M', '6.7M', '30M', '2.6M', '7.1M', '3.7M', '22M', '7.4M',
#        '6.4M', '3.2M', '8.2M', '9.9M', '4.9M', '9.5M', '5.0M', '5.9M',
#        '13M', '73M', '6.8M', '3.5M', '4.0M', '2.3M', '7.2M', '2.1M',
#        '42M', '7.3M', '9.1M', '55M', '23k', '6.5M', '1.5M', '7.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
#        '5.1M', '61M', '66M', '79k', '8.4M', '118k', '44M', '695k', '1.6M',
# ...

# %%
Playstore_apps_df['Size'].astype('string')
# Out:
# App
# Photo Editor & Candy Camera & Grid & ScrapBook         19M
# Coloring book moana                                    14M
# U Launcher Lite – FREE Live Cool Themes, Hide Apps    8.7M
# Sketch - Draw & Paint                                  25M
# Pixel Draw - Number Art Coloring Book                 2.8M
#                                                       ...
# FR Forms                                              9.6M
# Sya9a Maroc - FR                                       53M
# Fr. Mike Schmitz Audio Teachings                      3.6M
# Parkinson Exercices FR                                9.5M
# iHoroscope - 2018 Daily Horoscope & Astrology          19M
# Name: Size, Length: 8538, dtype: string

# %%
#Checking the unique values in Playstore_apps_df of 'Installs' column
Playstore_apps_df["Installs"].unique()
# Out:
# array([1.e+04, 5.e+05, 5.e+06, 5.e+07, 1.e+05, 5.e+04, 1.e+06, 1.e+07,
#        5.e+03, 1.e+08, 1.e+03, 5.e+08, 5.e+01, 1.e+02, 5.e+02, 1.e+01,
#        1.e+00, 5.e+00, 1.e+09, 0.e+00])

# %%
list(Playstore_apps_df["Installs"].unique())
# Out:
# [10000.0,
#  500000.0,
#  5000000.0,
#  50000000.0,
#  100000.0,
#  50000.0,
#  1000000.0,
#  10000000.0,
#  5000.0,
#  100000000.0,
#  1000.0,
#  500000000.0,
#  50.0,
#  100.0,
#  500.0,
#  10.0,
#  1.0,
#  5.0,
#  1000000000.0,
#  0.0]

# %%
Playstore_apps_df["Installs"].dtype
# Out:
# dtype('float64')

# %%
#Checking the unique values in Playstore_apps_df of 'Type' column
Playstore_apps_df["Type"].unique()
# Out:
# array(['Free', 'Paid'], dtype=object)

# %%
list(Playstore_apps_df["Type"].unique())
# Out:
# ['Free', 'Paid']

# %%
#cast data type in string
Playstore_apps_df["Type"].astype('string')
# Out:
# App
# Photo Editor & Candy Camera & Grid & ScrapBook        Free
# Coloring book moana                                   Free
# U Launcher Lite – FREE Live Cool Themes, Hide Apps    Free
# Sketch - Draw & Paint                                 Free
# Pixel Draw - Number Art Coloring Book                 Free
#                                                       ...
# FR Forms                                              Free
# Sya9a Maroc - FR                                      Free
# Fr. Mike Schmitz Audio Teachings                      Free
# Parkinson Exercices FR                                Free
# iHoroscope - 2018 Daily Horoscope & Astrology         Free
# Name: Type, Length: 8538, dtype: string

# %%
#Checking the unique values in Playstore_apps_df of 'Price' column
Playstore_apps_df["Price"].unique()
# Out:
# array([  0.  ,   6.99,   1.49,   2.99,   3.99,   7.99,   5.99,   4.99,
#          1.99,   9.99,   0.99,   1.  ,   3.49,  10.99,   7.49,   1.5 ,
#         14.99,  15.99,  74.99,  39.99,  29.99,   4.49,   1.7 ,   2.  ,
#          3.88,  25.99, 399.99,  17.99, 400.  ,   2.49,   3.02,   1.76,
#          4.84,   4.77,   1.61,  19.99,   1.59,   6.49,   1.29,   5.  ,
#         13.99, 299.99, 379.99,  37.99,  18.99, 389.99,  19.9 ,   8.49,
#          1.75,  14.  ,   4.85,  46.99, 109.99, 154.99,   3.08,   2.59,
#          4.8 ,   8.99,   1.96,  19.4 ,  15.46,  10.  ,   5.49,   3.04,
#         12.99,   4.29,   2.6 ,   3.28,   4.6 ,  28.99,   2.9 ,   1.97,
#         24.99, 200.  ,  89.99,   2.56,  30.99,   3.61, 394.99,   1.26,
#         16.99,   1.2 ,   1.04])

# %%
Playstore_apps_df["Price"].dtype
# Out:
# dtype('float64')

# %%
#Checking the unique values in Playstore_apps_df of 'Content Rating' column
Playstore_apps_df["Content Rating"].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated'], dtype=object)

# %%
list(Playstore_apps_df["Content Rating"].unique())
# Out:
# ['Everyone',
#  'Teen',
#  'Everyone 10+',
#  'Mature 17+',
#  'Adults only 18+',
#  'Unrated']

# %%
#Checking the unique values in Playstore_apps_df of 'Genres' column
Playstore_apps_df["Genres"].unique()
# Out:
# array(['Art & Design', 'Art & Design;Pretend Play',
#        'Art & Design;Creativity', 'Art & Design;Action & Adventure',
#        'Auto & Vehicles', 'Beauty', 'Books & Reference', 'Business',
#        'Comics', 'Comics;Creativity', 'Communication', 'Dating',
#        'Education', 'Education;Creativity', 'Education;Education',
#        'Education;Action & Adventure', 'Education;Pretend Play',
#        'Education;Brain Games', 'Entertainment',
#        'Entertainment;Brain Games', 'Entertainment;Music & Video',
#        'Events', 'Finance', 'Food & Drink', 'Health & Fitness',
#        'House & Home', 'Libraries & Demo', 'Lifestyle',
#        'Lifestyle;Pretend Play', 'Adventure;Action & Adventure', 'Arcade',
#        'Casual', 'Card', 'Casual;Pretend Play', 'Strategy', 'Action',
#        'Puzzle', 'Sports', 'Word', 'Racing', 'Casual;Creativity',
#        'Adventure', 'Board', 'Trivia', 'Simulation', 'Role Playing',
#        'Simulation;Education', 'Action;Action & Adventure',
# ...

# %%
#cast data type in string
Playstore_apps_df["Genres"].astype('string')
# Out:
# App
# Photo Editor & Candy Camera & Grid & ScrapBook                     Art & Design
# Coloring book moana                                   Art & Design;Pretend Play
# U Launcher Lite – FREE Live Cool Themes, Hide Apps                 Art & Design
# Sketch - Draw & Paint                                              Art & Design
# Pixel Draw - Number Art Coloring Book                   Art & Design;Creativity
#                                                                 ...
# FR Forms                                                               Business
# Sya9a Maroc - FR                                                      Education
# Fr. Mike Schmitz Audio Teachings                                      Education
# Parkinson Exercices FR                                                  Medical
# iHoroscope - 2018 Daily Horoscope & Astrology                         Lifestyle
# Name: Genres, Length: 8538, dtype: string

# %%
#Checking the unique values in Playstore_apps_df of 'Last Updated' column
Playstore_apps_df["Last Updated"].unique()
# Out:
# array(['07-01-2018', '15-01-2018', '01-08-2018', ..., '20-01-2014',
#        '16-02-2014', '23-03-2014'], dtype=object)

# %%
list(Playstore_apps_df["Last Updated"].unique())
# Out:
# ['07-01-2018',
#  '15-01-2018',
#  '01-08-2018',
#  '08-06-2018',
#  '20-06-2018',
#  '26-03-2017',
#  '26-04-2018',
#  '14-06-2018',
#  '20-09-2017',
#  '03-07-2018',
#  '27-10-2017',
#  '31-07-2018',
#  '02-04-2018',
#  '26-06-2018',
#  '03-08-2018',
#  '06-06-2018',
#  '07-11-2017',
#  '30-07-2018',
#  '20-04-2018',
#  '20-03-2018',
#  '12-07-2018',
#  '07-03-2018',
#  '07-07-2018',
#  '25-04-2018',
#  '11-10-2017',
#  '21-03-2018',
#  '22-08-2017',
#  '31-05-2018',
#  '19-07-2018',
#  '06-01-2018',
#  '27-04-2018',
#  '11-07-2018',
#  '02-08-2018',
#  '29-11-2017',
#  '31-03-2018',
#  '20-07-2018',
#  '15-04-2018',
#  '03-01-2018',
#  '14-11-2017',
#  '17-12-2017',
#  '28-05-2018',
#  '10-05-2018',
#  '26-07-2018',
#  '18-07-2018',
#  '29-07-2018',
#  '26-08-2014',
#  '08-07-2018',
#  '28-07-2018',
#  '12-06-2018',
#  '14-10-2016',
#  '16-07-2018',
#  '27-07-2018',
#  '04-07-2018',
#  '27-03-2018',
#  '15-07-2018',
#  '24-07-2018',
#  '23-07-2018',
#  '16-05-2018',
# ...

# %%
#changing data type to datetime 
Playstore_apps_df["Last Updated"] = pd.to_datetime(Playstore_apps_df["Last Updated"])

# %%
Playstore_apps_df["Last Updated"]
# Out:
# App
# Photo Editor & Candy Camera & Grid & ScrapBook       2018-07-01
# Coloring book moana                                  2018-01-15
# U Launcher Lite – FREE Live Cool Themes, Hide Apps   2018-01-08
# Sketch - Draw & Paint                                2018-08-06
# Pixel Draw - Number Art Coloring Book                2018-06-20
#                                                         ...
# FR Forms                                             2016-09-29
# Sya9a Maroc - FR                                     2017-07-25
# Fr. Mike Schmitz Audio Teachings                     2018-06-07
# Parkinson Exercices FR                               2017-01-20
# iHoroscope - 2018 Daily Horoscope & Astrology        2018-07-25
# Name: Last Updated, Length: 8538, dtype: datetime64[ns]

# %%
#Checking the unique values in Playstore_apps_df of 'Current Ver' column
Playstore_apps_df["Current Ver"].unique()
# Out:
# array(['1.0.0', '2.0.0', '1.2.4', ..., '1.0.612928', '0.3.4', '2.0.148.0'],
#       dtype=object)

# %%
#print the whole array
import sys
import numpy
numpy.set_printoptions(threshold=sys.maxsize)

# %%
Playstore_apps_df["Current Ver"].unique()
# Out:
# array(['1.0.0', '2.0.0', '1.2.4', 'Varies with device', '1.1', '1',
#        '6.1.61.1', '2.9.2', '2.8', '1.0.4', '1.0.15', '3.8', '1.2.3', nan,
#        '3.1', '2.2.5', '5.5.4', '4', '2.2.6.2', '1.1.3', '1.5', '1.0.8',
#        '1.03', '6', '6.7.12.2018', '1.2', '2.2', '1.1.0', '1.6', '2.1',
#        '1.0.9', '1.3', '2.0.1', '1.46', '1.6.1', '11', '3', '1.7.1',
#        '2.5.1', '1.0.1', '2.493', '1.9.1', '1.7', '2.20 Build 02', '1.37',
#        '0.2.1', '4.47.3', '1.9.7', '2.2.21', '1.79', '2.3.5.1', '8.31',
#        '1.1.5.0', '10.0.2', '1.10.3', '3.20.1', '1.0.3', '1.4', '2.8.2',
#        '4.0.3', '1.5.18', '2.3.4', '2.17', '6.10.1', '2.3.0', '1.0.6',
#        '1.9', '3.0.1', '8', '3.3.9', '2.3.09', '1.4.2', '18.5', '1.15',
#        '2', '1.2.13', '1.0.2.0', '3.1.89', '2.2.0', '1.9.2', '1.3.2',
#        '3.2.1', '2.0.075', '1.91180527', '9.1.363', '1.1.6', '2.3.18',
#        '15', '18.05.31+530', '3.12', '1.28', '6.0.8', '14', '3.05',
# ...

# %%
Playstore_apps_df = Playstore_apps_df[Playstore_apps_df["Current Ver"] != 'Varies with device']

# %%
Playstore_apps_df["Current Ver"].unique()
# Out:
# array(['1.0.0', '2.0.0', '1.2.4', '1.1', '1', '6.1.61.1', '2.9.2', '2.8',
#        '1.0.4', '1.0.15', '3.8', '1.2.3', nan, '3.1', '2.2.5', '5.5.4',
#        '4', '2.2.6.2', '1.1.3', '1.5', '1.0.8', '1.03', '6',
#        '6.7.12.2018', '1.2', '2.2', '1.1.0', '1.6', '2.1', '1.0.9', '1.3',
#        '2.0.1', '1.46', '1.6.1', '11', '3', '1.7.1', '2.5.1', '1.0.1',
#        '2.493', '1.9.1', '1.7', '2.20 Build 02', '1.37', '0.2.1',
#        '4.47.3', '1.9.7', '2.2.21', '1.79', '2.3.5.1', '8.31', '1.1.5.0',
#        '10.0.2', '1.10.3', '3.20.1', '1.0.3', '1.4', '2.8.2', '4.0.3',
#        '1.5.18', '2.3.4', '2.17', '6.10.1', '2.3.0', '1.0.6', '1.9',
#        '3.0.1', '8', '3.3.9', '2.3.09', '1.4.2', '18.5', '1.15', '2',
#        '1.2.13', '1.0.2.0', '3.1.89', '2.2.0', '1.9.2', '1.3.2', '3.2.1',
#        '2.0.075', '1.91180527', '9.1.363', '1.1.6', '2.3.18', '15',
#        '18.05.31+530', '3.12', '1.28', '6.0.8', '14', '3.05', '2.5.3',
# ...

# %%
#Checking the unique values in Playstore_apps_df of 'Android Ver' column
Playstore_apps_df["Android Ver"].unique()
# Out:
# array(['4.0.3 and up', '4.4 and up', '2.3 and up', '4.2 and up',
#        '3.0 and up', '4.1 and up', '4.0 and up', '2.2 and up',
#        '6.0 and up', '5.0 and up', '1.6 and up', '2.1 and up',
#        '5.1 and up', '1.5 and up', '7.0 and up', '4.3 and up',
#        '4.0.3 - 7.1.1', '2.0 and up', '2.3.3 and up', '3.2 and up',
#        '4.4W and up', '7.1 and up', '7.0 - 7.1.1', 'Varies with device',
#        '8.0 and up', '5.0 - 8.0', '3.1 and up', '2.0.1 and up',
#        '4.1 - 7.1.1', nan, '5.0 - 6.0', '1.0 and up', '2.2 - 7.1.1',
#        '5.0 - 7.1.1'], dtype=object)

# %%
Playstore_apps_df = Playstore_apps_df[Playstore_apps_df["Android Ver"] != 'Varies with device']

# %%
Playstore_apps_df["Android Ver"].unique()
# Out:
# array(['4.0.3 and up', '4.4 and up', '2.3 and up', '4.2 and up',
#        '3.0 and up', '4.1 and up', '4.0 and up', '2.2 and up',
#        '6.0 and up', '5.0 and up', '1.6 and up', '2.1 and up',
#        '5.1 and up', '1.5 and up', '7.0 and up', '4.3 and up',
#        '4.0.3 - 7.1.1', '2.0 and up', '2.3.3 and up', '3.2 and up',
#        '4.4W and up', '7.1 and up', '7.0 - 7.1.1', '8.0 and up',
#        '5.0 - 8.0', '3.1 and up', '2.0.1 and up', '4.1 - 7.1.1', nan,
#        '5.0 - 6.0', '1.0 and up', '2.2 - 7.1.1', '5.0 - 7.1.1'],
#       dtype=object)

# %% [markdown]
# B) PERFROMING TASK FOR Playstore_reviews_df :-

# %%
#Checking the unique values in Playstore_reviews_df of 'Translated_Review' column
Playstore_reviews_df["Translated_Review"].unique()
# Out:
# array(['Almost mobile phone',
#        'Very effective, efficient convenient find available jobs. Keep good work power 104 Job Search.',
#        'Easy intuitive', 'good searching job internship',
#        'Not bad, price little bit expensive', 'easy use!',
#        'job search results iOS e.g. security',
#        'Well, it is also the largest human bank in Taiwan. Can you please app ui?',
#        'So', 'Very good job hunt', 'Easy to use.', 'Good find job easily',
#        'Good meet good', 'Awesomeee', 'Why English version???',
#        'The operation interface & information content is richer than 1111, and it is also better to use/utility without flashing back.',
#        'Is the development method completed in the early days, the computer web version and the mobile app, the function seems to be short or not the same in the same function page. For example, the similar work function of similar companies is not in the app version.',
# ...

# %%
#Checking the unique values in Playstore_reviews_df of 'Sentiment' column
Playstore_reviews_df["Sentiment"].unique()
# Out:
# array(['Neutral', 'Positive', 'Negative'], dtype=object)

# %%
#Checking the unique values in Playstore_reviews_df of 'Sentiment_Polarity' column
Playstore_reviews_df["Sentiment_Polarity"].unique()
# Out:
# array([ 0.00000000e+00,  6.26666667e-01,  4.33333333e-01,  7.00000000e-01,
#        -1.12500000e-01,  5.41666667e-01,  9.10000000e-01,  5.66666667e-01,
#         2.50000000e-01,  1.66666667e-02,  2.33333333e-01,  4.66666667e-01,
#         5.16666667e-01,  3.82539683e-01,  2.88888889e-01,  5.71428571e-02,
#         5.54444444e-01,  4.50000000e-01,  6.90666667e-01, -1.00000000e+00,
#         2.36666667e-01,  2.77777778e-03, -3.90625000e-01, -3.25000000e-01,
#         7.50000000e-01,  3.50000000e-01,  1.70454545e-01,  2.50000000e-02,
#         2.83333333e-01, -3.08333333e-01,  4.00000000e-01, -5.00000000e-02,
#         1.00000000e+00,  1.36363636e-01,  5.00000000e-01,  2.85714286e-01,
#         6.00000000e-01,  2.00000000e-01,  1.66666667e-01, -8.68055556e-02,
#        -1.94444444e-01, -1.57142857e-01,  1.33333333e-01,  5.90909091e-02,
#        -4.00000000e-01,  1.93750000e-01,  2.00000000e-01,  1.50000000e-01,
# ...

# %%
#Checking the unique values in Playstore_reviews_df of 'Sentiment_Subjectivity' column
Playstore_reviews_df["Sentiment_Subjectivity"].unique()
# Out:
# array([0.        , 0.66666667, 0.83333333, 0.6       , 0.62222222,
#        0.1       , 0.78      , 0.71666667, 0.25      , 0.275     ,
#        0.6       , 0.63333333, 0.86666667, 0.58730159, 0.67460317,
#        0.14285714, 0.76666667, 0.45      , 0.73866667, 1.        ,
#        0.30166667, 0.36388889, 0.05      , 0.65      , 0.8       ,
#        0.55      , 0.45454545, 0.375     , 0.47777778, 0.45833333,
#        0.15      , 0.3       , 0.53571429, 0.5       , 0.33333333,
#        0.5625    , 0.32430556, 0.41666667, 0.7047619 , 0.71666667,
#        0.36363636, 0.4       , 0.50625   , 0.2       , 0.575     ,
#        0.7       , 0.52      , 0.975     , 0.35      , 0.36666667,
#        0.37777778, 0.57222222, 0.19166667, 0.45      , 0.65      ,
#        0.32590909, 0.41809524, 0.53277311, 0.58484848, 0.65277778,
#        0.52142857, 0.75      , 0.525     , 0.65090909, 0.92      ,
#        0.77083333, 0.7       , 0.57777778, 0.73666667, 0.66666667,
# ...

# %%
##Task ended##
